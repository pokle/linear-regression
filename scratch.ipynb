# %%
import matplotlib.pyplot as plt
from IPython import display

for i in range(0,10):
    plt.plot([1,2,3,4,i], color='grey')
else:
    plt.plot([1,2,3,4,i], color='red', label='final')
    
plt.legend()
